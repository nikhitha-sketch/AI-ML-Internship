# %%
# AI & ML Internship - Day 5
# Topic : Data Cleaning
# Description : Handling missing values, removing duplicates,
#               and preparing a clean dataset.
import pandas as pd
print("=" * 60)
print("          DATA CLEANING USING PANDAS")
print("=" * 60)
# Load Dataset
df = pd.read_csv("StudentsPerformance.csv")
# Dataset before cleaning
print("\nDataset Shape (Before Cleaning):")
print(df.shape)
# Check missing values
print("\nMissing Values")
print(df.isnull().sum())
# Check duplicate rows
print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Remove duplicate rows
df = df.drop_duplicates()
# Handle missing values
# (Numeric columns -> fill with mean)
numeric_columns = df.select_dtypes(include="number").columns
for column in numeric_columns:
    df[column] = df[column].fillna(df[column].mean())
# (Categorical columns -> fill with mode)
categorical_columns = df.select_dtypes(exclude="number").columns
for column in categorical_columns:
    df[column] = df[column].fillna(df[column].mode()[0])
# Dataset after cleaning
print("\nDataset Shape (After Cleaning):")
print(df.shape)
print("\nMissing Values After Cleaning")
print(df.isnull().sum())
print("\nDuplicate Rows After Cleaning:")
print(df.duplicated().sum())
# Statistical Summary
print("\nStatistical Summary")
print(df.describe())
# Save cleaned dataset
df.to_csv("StudentsPerformance_Cleaned.csv", index=False)
print("\nCleaned dataset saved as 'StudentsPerformance_Cleaned.csv'")
print("\nData Cleaning Completed Successfully!")
print("\nCleaning Summary")
print("----------------")
print(f"Total Records : {len(df)}")
print(f"Total Columns : {len(df.columns)}")
print("Dataset is ready for analysis and machine learning.")
# Out:
# ...
#           DATA CLEANING USING PANDAS
# ...
#
# Dataset Shape (Before Cleaning):
# (1000, 8)
#
# Missing Values
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
#
# Duplicate Rows:
# 0
#
# Dataset Shape (After Cleaning):
# (1000, 8)
#
# Missing Values After Cleaning
# gender                         0
# race/ethnicity                 0
# parental level of education    0
# lunch                          0
# test preparation course        0
# math score                     0
# reading score                  0
# writing score                  0
# dtype: int64
#
# Duplicate Rows After Cleaning:
# 0
#
# Statistical Summary
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# ...
